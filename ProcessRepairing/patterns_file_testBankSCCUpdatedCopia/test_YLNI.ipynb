# %%
import os
import os.path
from pathlib import Path
import pandas as pd
import pm4py
from pm4py.objects.petri_net.importer import importer as pnml_importer
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.algo.evaluation.replay_fitness import algorithm as replay_fitness_evaluator
from pm4py.algo.evaluation.precision import algorithm as precision_evaluator
from pm4py.algo.evaluation.simplicity import algorithm as simplicity_evaluator
from pm4py.algo.conformance.alignments.petri_net import algorithm as alignments

# %%
results_filename='C:/Users/lgenga/Google Drive/MaterialeFabio/BPI2017Denied/final_results.csv'
base_path = Path(os.path.dirname(results_filename))
eventlog_or= str(base_path / 'BPI2017Denied.xes')
log = xes_importer.apply(eventlog_or)
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=1, style=ProgressStyl…

# %%
#if os.path.exists(results_filename):
#    os.remove(results_filename)
    
df_result = pd.DataFrame(columns=['Sub','petriNet_PercFitTraces', 'petriNet_Fitness', 'petriNet_Precision', 'petriNet_Simp',
                                  'petriNet_arcs','petriNet_trans', 'petriNet_places', 'NLNI_PercFitTraces', 'NLNI_Fitness',
                                  'NLNI_Precision', 'NLNI_Simp','NLNI_arcs','NLNI_trans', 'NLNI_places', 'YLNI_PercFitTraces',
                                  'YLNI_Fitness','YLNI_Precision', 'YLNI_Simp','YLNI_arcs','YLNI_trans', 'YLNI_places'
                                 ])

for entry in os.scandir(base_path / 'test_repairing'):
    if entry.is_dir():
        res_mapping={}
        print("working on dir "+entry.name)
        for file in os.listdir(entry):
            if file.endswith(".pnml") and "YLNI" in file:
                #compute the values
                pnml_filename = str(base_path / f'test_repairing/{entry.name}/{file}')
                print("analyzing net "+file)
                net, initial_marking, final_marking = pnml_importer.apply(pnml_filename)
                
                fitness = replay_fitness_evaluator.apply(log, net, initial_marking, final_marking, variant=replay_fitness_evaluator.Variants.ALIGNMENT_BASED)
                print("fitness" + str(fitness['averageFitness']))
                
                prec = precision_evaluator.apply(log, net, initial_marking, final_marking, variant=precision_evaluator.Variants.ALIGN_ETCONFORMANCE)
                print("precision" + str(prec))

                simp = simplicity_evaluator.apply(net)
                print("simplicity" + str(simp))
                
                arcs=len(net.arcs)
                trans=len(net.transitions)
                places=len(net.places)
                
                #fill the dictionary
                net_tokens=file.split("_")
                last_el=net_tokens[-1].replace(".pnml","")
                res_mapping[last_el+"_percFitTrace"]=fitness['percFitTraces']
                res_mapping[last_el+"_fit"]=fitness['averageFitness']
                res_mapping[last_el+"_prec"]=prec
                res_mapping[last_el+"_simp"]=simp
                res_mapping[last_el+"_arcs"]=arcs
                res_mapping[last_el+"_trans"]=trans
                res_mapping[last_el+"_places"]=places


        #update the results file
        df_result = df_result.append({'Sub': entry.name, 'petriNet_PercFitTraces':res_mapping.get("petriNet_percFitTrace"), 'petriNet_Fitness':res_mapping.get("petriNet_fit"),
                                      'petriNet_Precision':res_mapping.get("petriNet_prec"),'petriNet_Simp':res_mapping.get("petriNet_simp"), 'petriNet_arcs':res_mapping.get("petriNet_arcs"),
                                      'petriNet_trans':res_mapping.get("petriNet_trans"), 'petriNet_places':res_mapping.get("petriNet_places"),'NLNI_PercFitTraces': res_mapping.get("NLNI_percFitTrace"),
                                      'NLNI_Fitness':res_mapping.get("NLNI_fit"),'NLNI_Precision':res_mapping.get("NLNI_prec"),'NLNI_Simp':res_mapping.get("NLNI_simp"), 
                                      'NLNI_arcs':res_mapping.get("NLNI_arcs"),'NLNI_trans':res_mapping.get("NLNI_trans"), 'NLNI_places':res_mapping.get("NLNI_places"),
                                      'YLNI_PercFitTraces': res_mapping.get("YLNI_percFitTrace"),'YLNI_Fitness':res_mapping.get("YLNI_fit"),'YLNI_Precision':res_mapping.get("YLNI_prec"),
                                      'YLNI_Simp':res_mapping.get("YLNI_simp"),'YLNI_arcs':res_mapping.get("YLNI_arcs"),'YLNI_trans':res_mapping.get("YLNI_trans"), 'YLNI_places':res_mapping.get("YLNI_places")}, ignore_index=True)
        df_result.to_csv(results_filename, sep=";")
# Out:
# working on dir Sub_29
# analyzing net repaired_Sub29_petriNet_NLNI.pnml
# fitness0.967741935483871
# HBox(children=(IntProgress(value=0, description='computing precision with alignments, completed variants :: ',…
# precision0.049079754601227044
# simplicity0.4601769911504425
# analyzing net repaired_Sub29_petriNet_YLNI.pnml
# fitness0.967741935483871
# HBox(children=(IntProgress(value=0, description='computing precision with alignments, completed variants :: ',…
# precision0.049079754601227044
# simplicity0.4601769911504425
# working on dir Sub_31
# analyzing net repaired_Sub31_petriNet_NLNI.pnml
# fitness1.0
# HBox(children=(IntProgress(value=0, description='computing precision with alignments, completed variants :: ',…
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-3-c22706f30c8d> in <module>
#      19                 print("fitness" + str(fitness['averageFitness']))
#      20
# ---> 21                 prec = precision_evaluator.apply(log, net, initial_marking, final_marking, variant=precision_evaluator.Variants.ALIGN_ETCONFORMANCE)
#      22                 print("precision" + str(prec))
#      23
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\pm4py\algo\evaluation\precision\algorithm.py in apply(log, net, marking, final_marking, parameters, variant)
#      74
#      75     return exec_utils.get_variant(variant).apply(log, net, marking,
# ---> 76                              final_marking, parameters=parameters)
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\pm4py\algo\evaluation\precision\variants\align_etconformance.py in apply(log, net, marking, final_marking, parameters)
#      93                 # for each prefix
#      94                 activated_transitions_labels = activated_transitions_labels.union(
# ---> 95                     x.label for x in utils.get_visible_transitions_eventually_enabled_by_marking(net, m) if
#      96                     x.label is not None)
#      97             escaping_edges = activated_transitions_labels.difference(log_transitions)
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\pm4py\objects\petri_net\utils\align_utils.py in get_visible_transitions_eventually_enabled_by_marking(net, marking)
#     432                         all_enabled_transitions.append(t2)
#     433                         all_enabled_transitions_marking_dictio[t2] = new_marking
# --> 434             visited_transitions.add(repr([t, marking_copy]))
#     435         i = i + 1
#     436
#
# MemoryError:

# %%
res_mapping
# Out:
# {'petriNet.pnml_percFitTrace': 0.10025062656641603,
#  'petriNet.pnml_fit': 0.8592640101019519,
#  'petriNet.pnml_prec': 0.9633569739952719,
#  'petriNet.pnml_simp': 0.726027397260274,
#  'NLNI.pnml_percFitTrace': 0.0,
#  'NLNI.pnml_fit': 0.6688657770961118,
#  'NLNI.pnml_prec': 0.5275536338850486,
#  'NLNI.pnml_simp': 0.4444444444444444,
#  'YLNI.pnml_percFitTrace': 0.0,
#  'YLNI.pnml_fit': 0.7889723428886077,
#  'YLNI.pnml_prec': 0.5288590604026846,
#  'YLNI.pnml_simp': 0.4601769911504425,
#  'YLYI.pnml_percFitTrace': 5.964912280701754,
#  'YLYI.pnml_fit': 0.8307768537293282,
#  'YLYI.pnml_prec': 0.3081990219873131,
#  'YLYI.pnml_simp': 0.4444444444444444}

# %%
df_result = df_result.append({'Sub': entry.name, 'NLNI_PercFitTraces': res_mapping["NLNI.pnml_percFitTrace"] ,'NLNI_Fitness':res_mapping["NLNI.pnml_fit"],
                                    'NLNI_Precision':res_mapping["NLNI.pnml_prec"],'NLNI_Simp':res_mapping["NLNI.pnml_simp"],
                                    'YLNI_PercFitTraces': res_mapping["YLNI.pnml_percFitTrace"] , 'YLNI_Fitness':res_mapping["YLNI.pnml_fit"],
                                    'YLNI_Precision':res_mapping["YLNI.pnml_prec"],'YLNI_Simp':res_mapping["YLNI.pnml_simp"],
                                    'YLYI_PercFitTraces': res_mapping.get("YLYI.pnml_percFitTrace") , 'YLYI_Fitness':res_mapping.get("YLYI.pnml_fit"),
                                    'YLYI_Precision':res_mapping.get("YLYI.pnml_prec"),'YLYI_Simp':res_mapping.get("YLYI.pnml_simp")}, ignore_index=True)

# %%
df_result
# Out:
#       Sub  NLNI_PercFitTraces  NLNI_Fitness  NLNI_Precision  NLNI_Simp  \
# 0  Sub_29                 0.0      0.668866        0.527554   0.444444
#
#    YLNI_PercFitTraces  YLNI_Fitness  YLNI_Precision  YLNI_Simp  \
# 0                 0.0      0.788972        0.528859   0.460177
#
#    YLYI_PercFitTraces  YLYI_Fitness  YLYI_Precision  YLYI_Simp
# 0            5.964912      0.830777        0.308199   0.444444

# %%
net_test, initial_marking, final_marking = pnml_importer.apply(str(base_path / f'test_repairing/Sub_29/repaired_Sub29_petriNet_NLNI.pnml'))
fitness_tes = replay_fitness_evaluator.apply(log, net_test, initial_marking, final_marking, variant=replay_fitness_evaluator.Variants.ALIGNMENT_BASED)
# Out:
# HBox(children=(IntProgress(value=0, description='aligning log, completed variants :: ', max=1915, style=Progre…

# %%
aligned_traces = alignments.apply_log(log, net_test, initial_marking, final_marking)
# Out:
# HBox(children=(IntProgress(value=0, description='aligning log, completed variants :: ', max=1915, style=Progre…

# %%
aligned_traces
# Out:
# [{'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('AHRRPC', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30016,
#   'visited_states': 325,
#   'queued_states': 791,
#   'traversed_arcs': 2958,
#   'lp_solved': 246,
#   'fitness': 0.90625},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 115,
#   'queued_states': 280,
#   'traversed_arcs': 1153,
#   'lp_solved': 163,
#   'fitness': 0.8421052631578947},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('SHRRP', 'SHRRP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('SRP', 'SRP'),
#    ('FRP', 'FRP'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('HRRAN', 'HRRAN'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70039,
#   'visited_states': 544,
#   'queued_states': 1249,
#   'traversed_arcs': 4071,
#   'lp_solved': 634,
#   'fitness': 0.8157894736842105},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20004,
#   'visited_states': 103,
#   'queued_states': 250,
#   'traversed_arcs': 1016,
#   'lp_solved': 88,
#   'fitness': 0.8947368421052632},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRIRV', '>>'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30016,
#   'visited_states': 155,
#   'queued_states': 375,
#   'traversed_arcs': 1375,
#   'lp_solved': 167,
#   'fitness': 0.85},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('SHRRP', '>>'),
#    ('>>', None)],
#   'cost': 80027,
#   'visited_states': 441,
#   'queued_states': 979,
#   'traversed_arcs': 3306,
#   'lp_solved': 502,
#   'fitness': 0.7241379310344828},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30015,
#   'visited_states': 130,
#   'queued_states': 333,
#   'traversed_arcs': 1201,
#   'lp_solved': 196,
#   'fitness': 0.8421052631578947},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', '>>'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30015,
#   'visited_states': 183,
#   'queued_states': 454,
#   'traversed_arcs': 1661,
#   'lp_solved': 174,
#   'fitness': 0.8636363636363636},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('LRIRV', '>>'),
#    ('FLRRP', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FHRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20004,
#   'visited_states': 252,
#   'queued_states': 634,
#   'traversed_arcs': 2666,
#   'lp_solved': 154,
#   'fitness': 0.9393939393939394},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('>>', None),
#    ('LRRR', 'LRRR'),
#    ('SRP', 'SRP'),
#    ('FRP', 'FRP'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('>>', None),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 80020,
#   'visited_states': 511,
#   'queued_states': 1113,
#   'traversed_arcs': 3729,
#   'lp_solved': 500,
#   'fitness': 0.7419354838709677},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRIRV', '>>'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30016,
#   'visited_states': 155,
#   'queued_states': 375,
#   'traversed_arcs': 1375,
#   'lp_solved': 167,
#   'fitness': 0.85},
#  {'alignment': [('>>', None),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRHA', 'HRHA'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('HRRAN', 'HRRAN'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70016,
#   'visited_states': 233,
#   'queued_states': 555,
#   'traversed_arcs': 1558,
#   'lp_solved': 254,
#   'fitness': 0.6818181818181819},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('HRRAN', 'HRRAN'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70015,
#   'visited_states': 261,
#   'queued_states': 591,
#   'traversed_arcs': 1941,
#   'lp_solved': 256,
#   'fitness': 0.6818181818181819},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('SLRRP', '>>'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30015,
#   'visited_states': 172,
#   'queued_states': 416,
#   'traversed_arcs': 1523,
#   'lp_solved': 182,
#   'fitness': 0.8571428571428572},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('AHRRPC', '>>'),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 148,
#   'queued_states': 361,
#   'traversed_arcs': 1352,
#   'lp_solved': 141,
#   'fitness': 0.8571428571428572},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRIRV', '>>'),
#    ('EPP', '>>'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('FLRRP', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20009,
#   'visited_states': 215,
#   'queued_states': 558,
#   'traversed_arcs': 2268,
#   'lp_solved': 149,
#   'fitness': 0.9285714285714286},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 60027,
#   'visited_states': 145,
#   'queued_states': 400,
#   'traversed_arcs': 1790,
#   'lp_solved': 200,
#   'fitness': 0.7391304347826086},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRHA', 'HRHA'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('FLRRP', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 50021,
#   'visited_states': 112,
#   'queued_states': 309,
#   'traversed_arcs': 1341,
#   'lp_solved': 160,
#   'fitness': 0.782608695652174},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('FLRRP', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 10015,
#   'visited_states': 53,
#   'queued_states': 171,
#   'traversed_arcs': 592,
#   'lp_solved': 94,
#   'fitness': 0.9473684210526316},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRHA', 'HRHA'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 80022,
#   'visited_states': 295,
#   'queued_states': 671,
#   'traversed_arcs': 1908,
#   'lp_solved': 333,
#   'fitness': 0.7037037037037037},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('HRHA', 'HRHA'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SRP', 'SRP'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 90028,
#   'visited_states': 553,
#   'queued_states': 1264,
#   'traversed_arcs': 3823,
#   'lp_solved': 580,
#   'fitness': 0.7906976744186046},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('AHRRPC', 'AHRRPC'),
#    ('HRRAN', 'HRRAN'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 70026,
#   'visited_states': 196,
#   'queued_states': 591,
#   'traversed_arcs': 2459,
#   'lp_solved': 358,
#   'fitness': 0.78125},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 80016,
#   'visited_states': 266,
#   'queued_states': 625,
#   'traversed_arcs': 1823,
#   'lp_solved': 290,
#   'fitness': 0.6799999999999999},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('HRRAN', 'HRRAN'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRAN', 'HRRAN'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 90021,
#   'visited_states': 173,
#   'queued_states': 498,
#   'traversed_arcs': 2211,
#   'lp_solved': 248,
#   'fitness': 0.7352941176470589},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20016,
#   'visited_states': 105,
#   'queued_states': 266,
#   'traversed_arcs': 1028,
#   'lp_solved': 95,
#   'fitness': 0.8947368421052632},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('FLRRP', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 4,
#   'visited_states': 18,
#   'queued_states': 73,
#   'traversed_arcs': 144,
#   'lp_solved': 9,
#   'fitness': 1.0},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('FHRRPC', '>>'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30015,
#   'visited_states': 155,
#   'queued_states': 388,
#   'traversed_arcs': 1369,
#   'lp_solved': 151,
#   'fitness': 0.8571428571428572},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('RBPC', '>>'),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', '>>'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 40014,
#   'visited_states': 444,
#   'queued_states': 1073,
#   'traversed_arcs': 3898,
#   'lp_solved': 383,
#   'fitness': 0.8888888888888888},
#  {'alignment': [('>>', None),
#    ('SRPP', 'SRPP'),
#    ('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20009,
#   'visited_states': 297,
#   'queued_states': 740,
#   'traversed_arcs': 3104,
#   'lp_solved': 166,
#   'fitness': 0.9411764705882353},
#  {'alignment': [('>>', None),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRHA', 'HRHA'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70023,
#   'visited_states': 445,
#   'queued_states': 1030,
#   'traversed_arcs': 3268,
#   'lp_solved': 485,
#   'fitness': 0.7878787878787878},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20004,
#   'visited_states': 103,
#   'queued_states': 255,
#   'traversed_arcs': 1019,
#   'lp_solved': 83,
#   'fitness': 0.8947368421052632},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRIRV', '>>'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 40015,
#   'visited_states': 181,
#   'queued_states': 431,
#   'traversed_arcs': 1545,
#   'lp_solved': 245,
#   'fitness': 0.8},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 70021,
#   'visited_states': 134,
#   'queued_states': 387,
#   'traversed_arcs': 1645,
#   'lp_solved': 179,
#   'fitness': 0.72},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 10003,
#   'visited_states': 17,
#   'queued_states': 66,
#   'traversed_arcs': 121,
#   'lp_solved': 33,
#   'fitness': 0.9473684210526316},
#  {'alignment': [('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('FHRRP', '>>'),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30019,
#   'visited_states': 351,
#   'queued_states': 938,
#   'traversed_arcs': 3574,
#   'lp_solved': 233,
#   'fitness': 0.9166666666666666},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', '>>'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 236,
#   'queued_states': 580,
#   'traversed_arcs': 2329,
#   'lp_solved': 200,
#   'fitness': 0.8888888888888888},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('LRIRV', 'LRIRV'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 80038,
#   'visited_states': 486,
#   'queued_states': 1150,
#   'traversed_arcs': 3726,
#   'lp_solved': 665,
#   'fitness': 0.7714285714285715},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('SRP', 'SRP'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('LRRR', 'LRRR'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('FRP', 'FRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 90025,
#   'visited_states': 759,
#   'queued_states': 1691,
#   'traversed_arcs': 5903,
#   'lp_solved': 686,
#   'fitness': 0.8125},
#  {'alignment': [('>>', None),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('SRP', 'SRP'),
#    ('FRP', 'FRP'),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70016,
#   'visited_states': 273,
#   'queued_states': 637,
#   'traversed_arcs': 2063,
#   'lp_solved': 297,
#   'fitness': 0.6956521739130435},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('HRHA', 'HRHA'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 60015,
#   'visited_states': 111,
#   'queued_states': 310,
#   'traversed_arcs': 1332,
#   'lp_solved': 168,
#   'fitness': 0.7391304347826086},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('LRRR', 'LRRR'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('LRERV', 'LRERV'),
#    ('HRRAN', 'HRRAN'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 60021,
#   'visited_states': 335,
#   'queued_states': 879,
#   'traversed_arcs': 3691,
#   'lp_solved': 499,
#   'fitness': 0.8333333333333334},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 60009,
#   'visited_states': 39,
#   'queued_states': 141,
#   'traversed_arcs': 422,
#   'lp_solved': 78,
#   'fitness': 0.7142857142857143},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 80037,
#   'visited_states': 497,
#   'queued_states': 1116,
#   'traversed_arcs': 3754,
#   'lp_solved': 558,
#   'fitness': 0.7777777777777778},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('LRIRV', '>>'),
#    ('FLRRP', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20015,
#   'visited_states': 95,
#   'queued_states': 260,
#   'traversed_arcs': 1003,
#   'lp_solved': 155,
#   'fitness': 0.9},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('FHRRP', '>>'),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 150,
#   'queued_states': 365,
#   'traversed_arcs': 1356,
#   'lp_solved': 142,
#   'fitness': 0.8571428571428572},
#  {'alignment': [('>>', None),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('FLRRP', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 4,
#   'visited_states': 17,
#   'queued_states': 67,
#   'traversed_arcs': 121,
#   'lp_solved': 8,
#   'fitness': 1.0},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70009,
#   'visited_states': 140,
#   'queued_states': 380,
#   'traversed_arcs': 864,
#   'lp_solved': 156,
#   'fitness': 0.6818181818181819},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('LRERV', 'LRERV'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('FLRRP', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 15,
#   'visited_states': 51,
#   'queued_states': 166,
#   'traversed_arcs': 579,
#   'lp_solved': 21,
#   'fitness': 1.0},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('SRP', 'SRP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('SRPP', '>>'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30015,
#   'visited_states': 365,
#   'queued_states': 855,
#   'traversed_arcs': 3269,
#   'lp_solved': 251,
#   'fitness': 0.9117647058823529},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 80021,
#   'visited_states': 304,
#   'queued_states': 673,
#   'traversed_arcs': 2069,
#   'lp_solved': 309,
#   'fitness': 0.6363636363636364},
#  {'alignment': [('>>', None),
#    ('FLRRP', 'FLRRP'),
#    ('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('LRIRV', '>>'),
#    ('FLRRP', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 10004,
#   'visited_states': 93,
#   'queued_states': 260,
#   'traversed_arcs': 1103,
#   'lp_solved': 51,
#   'fitness': 0.9545454545454546},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('SRP', 'SRP'),
#    ('FRP', 'FRP'),
#    ('HRRAN', 'HRRAN'),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('AHRRPC', 'AHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 50021,
#   'visited_states': 167,
#   'queued_states': 442,
#   'traversed_arcs': 1827,
#   'lp_solved': 262,
#   'fitness': 0.7727272727272727},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20004,
#   'visited_states': 101,
#   'queued_states': 248,
#   'traversed_arcs': 1012,
#   'lp_solved': 88,
#   'fitness': 0.8947368421052632},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRIRV', '>>'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30008,
#   'visited_states': 172,
#   'queued_states': 431,
#   'traversed_arcs': 1635,
#   'lp_solved': 174,
#   'fitness': 0.8636363636363636},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
# ...
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 90033,
#   'visited_states': 631,
#   'queued_states': 1425,
#   'traversed_arcs': 4612,
#   'lp_solved': 686,
#   'fitness': 0.7954545454545454},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('>>', 'FRP'),
#    ('FLRRP', '>>'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 112,
#   'queued_states': 274,
#   'traversed_arcs': 1147,
#   'lp_solved': 170,
#   'fitness': 0.8421052631578947},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('EPP', 'EPP'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 90021,
#   'visited_states': 412,
#   'queued_states': 912,
#   'traversed_arcs': 3041,
#   'lp_solved': 415,
#   'fitness': 0.7096774193548387},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('LRIRV', '>>'),
#    ('>>', 'FLRRP'),
#    ('AHRRPC', '>>'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 40032,
#   'visited_states': 330,
#   'queued_states': 794,
#   'traversed_arcs': 2758,
#   'lp_solved': 268,
#   'fitness': 0.8620689655172413},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('LRERV', 'LRERV'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20003,
#   'visited_states': 125,
#   'queued_states': 318,
#   'traversed_arcs': 1293,
#   'lp_solved': 98,
#   'fitness': 0.9047619047619048},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRERV', 'LRERV'),
#    ('LRIRV', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('REPC', '>>'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 146,
#   'queued_states': 372,
#   'traversed_arcs': 1348,
#   'lp_solved': 158,
#   'fitness': 0.8571428571428572},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRHA', 'HRHA'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('LRRR', 'LRRR'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 80015,
#   'visited_states': 280,
#   'queued_states': 697,
#   'traversed_arcs': 3087,
#   'lp_solved': 358,
#   'fitness': 0.75},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20019,
#   'visited_states': 319,
#   'queued_states': 816,
#   'traversed_arcs': 3382,
#   'lp_solved': 149,
#   'fitness': 0.9444444444444444},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SLRRP', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 20014,
#   'visited_states': 205,
#   'queued_states': 538,
#   'traversed_arcs': 2132,
#   'lp_solved': 148,
#   'fitness': 0.9259259259259259},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 121,
#   'queued_states': 306,
#   'traversed_arcs': 1179,
#   'lp_solved': 179,
#   'fitness': 0.8421052631578947},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('SHRRPC', '>>'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 80026,
#   'visited_states': 511,
#   'queued_states': 1215,
#   'traversed_arcs': 3860,
#   'lp_solved': 484,
#   'fitness': 0.7777777777777778},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('HRRAN', 'HRRAN'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('>>', 'FRP'),
#    ('>>', None)],
#   'cost': 90027,
#   'visited_states': 392,
#   'queued_states': 846,
#   'traversed_arcs': 2662,
#   'lp_solved': 380,
#   'fitness': 0.6666666666666667},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('SHRRP', 'SHRRP'),
#    ('SHRRPC', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('HRRAN', 'HRRAN'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('RHRRPC', 'RHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('FRP', 'FRP'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 90021,
#   'visited_states': 386,
#   'queued_states': 891,
#   'traversed_arcs': 2709,
#   'lp_solved': 386,
#   'fitness': 0.7272727272727273},
#  {'alignment': [('SRP', 'SRP'),
#    ('SRPP', 'SRPP'),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('SRP', 'SRP'),
#    ('FRP', 'FRP'),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('HRHA', 'HRHA'),
#    ('SHRRPC', '>>'),
#    ('AHRRPC', 'AHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70023,
#   'visited_states': 353,
#   'queued_states': 823,
#   'traversed_arcs': 2550,
#   'lp_solved': 417,
#   'fitness': 0.75},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('EPP', 'EPP'),
#    ('SRP', 'SRP'),
#    ('FRP', 'FRP'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('>>', None),
#    ('HRHA', 'HRHA'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FHRRPC', 'FHRRPC'),
#    ('HRRR', 'HRRR'),
#    ('>>', None),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRIRV'),
#    ('>>', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70026,
#   'visited_states': 325,
#   'queued_states': 750,
#   'traversed_arcs': 2484,
#   'lp_solved': 353,
#   'fitness': 0.72},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('REPC', 'REPC'),
#    ('RBPC', 'RBPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('REPP', 'REPP'),
#    ('SRPP', 'SRPP'),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('FRPP', 'FRPP'),
#    ('EPP', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('LRIRV', 'LRIRV'),
#    ('LRIRV', '>>'),
#    ('LRERV', 'LRERV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('LRRR', 'LRRR'),
#    ('FLRRP', '>>'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 40016,
#   'visited_states': 342,
#   'queued_states': 833,
#   'traversed_arcs': 3122,
#   'lp_solved': 489,
#   'fitness': 0.8709677419354839},
#  {'alignment': [('SRP', 'SRP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('RBPC', 'RBPC'),
#    ('REPC', 'REPC'),
#    ('RIBPC', 'RIBPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('REPP', 'REPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('FRPP', 'FRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('RIBPC', 'RIBPC'),
#    ('REPC', 'REPC'),
#    ('>>', None),
#    ('>>', None),
#    ('SRPP', 'SRPP'),
#    ('>>', None),
#    ('>>', None),
#    ('SRP', 'SRP'),
#    ('FRP', 'FRP'),
#    ('SHRRPC', '>>'),
#    ('MHRRPC', 'MHRRPC'),
#    ('FHRRPC', 'FHRRPC'),
#    ('>>', None),
#    ('HRRAN', 'HRRAN'),
#    ('HRHA', 'HRHA'),
#    ('HRRR', 'HRRR'),
#    ('FHRRP', 'FHRRP'),
#    ('>>', None),
#    ('>>', 'EPP'),
#    ('>>', None),
#    ('>>', 'SLRRP'),
#    ('>>', 'LRERV'),
#    ('>>', 'LRIRV'),
#    ('>>', None),
#    ('>>', 'FLRRP'),
#    ('>>', 'LRRR'),
#    ('FRP', 'FRP'),
#    ('>>', None)],
#   'cost': 70028,
#   'visited_states': 296,
#   'queued_states': 732,
#   'traversed_arcs': 1987,
#   'lp_solved': 376,
#   'fitness': 0.75},
#  ...]

# %%
fitness_tes
# Out:
# {'percFitTraces': 5.964912280701754,
#  'averageFitness': 0.8307768537293282,
#  'percentage_of_fitting_traces': 5.964912280701754,
#  'average_trace_fitness': 0.8307768537293282}
